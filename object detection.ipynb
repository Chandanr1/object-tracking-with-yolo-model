# %% [markdown]
# <a href="https://colab.research.google.com/github/Chandanr1/object-tracking-with-yolo-model/blob/main/object%20detection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="pm571SrqMVMdrwMCAUBb")
project = rf.workspace("vehicle-classfication").project("vehicle-classification-v5")
version = project.version(1)
dataset = version.download("yolov11")
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 88.6/88.6 kB 3.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.8/66.8 kB 6.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.9/49.9 MB 14.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 18.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.2/4.2 MB 38.7 MB/s eta 0:00:00
# ...
#   Attempting uninstall: opencv-python-headless
#     Found existing installation: opencv-python-headless 4.12.0.88
#     Uninstalling opencv-python-headless-4.12.0.88:
#       Successfully uninstalled opencv-python-headless-4.12.0.88
#   Attempting uninstall: idna
#     Found existing installation: idna 3.10
#     Uninstalling idna-3.10:
#       Successfully uninstalled idna-3.10
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to Vehicle-Classification-V5-1 in yolov11:: 100%|██████████| 37562/37562 [00:22<00:00, 1656.60it/s]

# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 17.9 MB/s eta 0:00:00
# ...

# %%
from ultralytics import YOLO
model=YOLO('yolo11n.pt')
model.train(data='/content/Vehicle-Classification-V5-1/data.yaml',epochs=10)
# Out:
# Ultralytics 8.3.187 🚀 Python-3.12.11 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
model.predict(source='/content/Vehicle-Classification-V5-1/test/images/00812_jpg.rf.bfb9b981f12d7ea16081dea3988001b0.jpg',save=True)
# Out:
# image 1/1 /content/Vehicle-Classification-V5-1/test/images/00812_jpg.rf.bfb9b981f12d7ea16081dea3988001b0.jpg: 480x640 1 Pickup, 219.9ms
# Speed: 4.1ms preprocess, 219.9ms inference, 8.5ms postprocess per image at shape (1, 3, 480, 640)
# Results saved to runs/detect/train22
# [ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'Construction', 1: 'LargeCV', 2: 'MediumCV', 3: 'PassengerCarrying', 4: 'Pickup', 5: 'PrivateVehicle', 6: 'Probe', 7: 'SmallCV', 8: 'Trailer', 9: 'TwoWheel', 10: 'Van'}
#  obb: None
#  orig_img: array([[[246, 246, 246],
#          [249, 249, 249],
#          [252, 252, 252],
#          ...,
#          [254, 254, 254],
#          [253, 253, 253],
#          [252, 252, 252]],
#
#         [[248, 248, 248],
#          [250, 250, 250],
#          [252, 252, 252],
#          ...,
#          [254, 254, 254],
#          [253, 253, 253],
# ...

# %%
show_image('/content/runs/detect/train22/00812_jpg.rf.bfb9b981f12d7ea16081dea3988001b0.jpg')
# Out:
# <PIL.Image.Image image mode=RGB size=320x240>

# %%
import cv2
from google.colab.patches import cv2_imshow
def show_image(path):
  im=cv2.imread(path)
  cv2_imshow(im)

# %%
model.predict(source='/content/Vehicle-Classification-V5-1/test/images/07287_jpg.rf.2e9207431d1a8c2752ebedcab869cb2e.jpg',save=True)
# Out:
# image 1/1 /content/Vehicle-Classification-V5-1/test/images/07287_jpg.rf.2e9207431d1a8c2752ebedcab869cb2e.jpg: 480x640 1 Pickup, 17.8ms
# Speed: 12.0ms preprocess, 17.8ms inference, 2.9ms postprocess per image at shape (1, 3, 480, 640)
# Results saved to runs/detect/train23
# [ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'Construction', 1: 'LargeCV', 2: 'MediumCV', 3: 'PassengerCarrying', 4: 'Pickup', 5: 'PrivateVehicle', 6: 'Probe', 7: 'SmallCV', 8: 'Trailer', 9: 'TwoWheel', 10: 'Van'}
#  obb: None
#  orig_img: array([[[253, 253, 253],
#          [253, 253, 253],
#          [253, 253, 253],
#          ...,
#          [254, 254, 254],
#          [254, 254, 254],
#          [254, 254, 254]],
#
#         [[253, 253, 253],
#          [253, 253, 253],
#          [253, 253, 253],
#          ...,
#          [254, 254, 254],
#          [254, 254, 254],
# ...

# %%
show_image('/content/runs/detect/train23/07287_jpg.rf.2e9207431d1a8c2752ebedcab869cb2e.jpg')
# Out:
# <PIL.Image.Image image mode=RGB size=1024x768>

# %%
model.predict(source='/content/Vehicle-Classification-V5-1/test/images/20170418075502-550_color-ROI-1-84_jpg.rf.e10ecfc1eb3c8932d3e8d758031c0417.jpg',save=True)
# Out:
# image 1/1 /content/Vehicle-Classification-V5-1/test/images/20170418075502-550_color-ROI-1-84_jpg.rf.e10ecfc1eb3c8932d3e8d758031c0417.jpg: 224x640 1 PrivateVehicle, 1 Probe, 1 SmallCV, 57.9ms
# Speed: 2.0ms preprocess, 57.9ms inference, 1.7ms postprocess per image at shape (1, 3, 224, 640)
# Results saved to runs/detect/train24
# [ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'Construction', 1: 'LargeCV', 2: 'MediumCV', 3: 'PassengerCarrying', 4: 'Pickup', 5: 'PrivateVehicle', 6: 'Probe', 7: 'SmallCV', 8: 'Trailer', 9: 'TwoWheel', 10: 'Van'}
#  obb: None
#  orig_img: array([[[188, 188, 188],
#          [188, 188, 188],
#          [188, 188, 188],
#          ...,
#          [255, 255, 255],
#          [255, 255, 255],
#          [255, 255, 255]],
#
#         [[188, 188, 188],
#          [188, 188, 188],
#          [188, 188, 188],
#          ...,
#          [255, 255, 255],
# ...

# %%
show_image('/content/runs/detect/train24/20170418075502-550_color-ROI-1-84_jpg.rf.e10ecfc1eb3c8932d3e8d758031c0417.jpg')
# Out:
# <PIL.Image.Image image mode=RGB size=1920x664>
